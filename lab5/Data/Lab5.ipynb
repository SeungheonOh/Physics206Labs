# %%
# %run ./momentum_conservation.ipynb
# Out:
# Intertia before 0.00097
# Intertia after 0.0011419965578813671
# Avg angular velocity before:  6.407449982965062 . uncertainty:  0.3969701001641433
# Avg angular velocity after:  4.060662020608665 . uncertainty:  0.03651575039462736
# Avg angular momentum before:  0.00621522648347611 . uncertainty:  0.000385060997159219
# Avg angular momentum after:  0.00463708159095187 . uncertainty:  4.1700158346594446e-05

# %%
CSV_INPUT = "./C.csv"
# %run ./find_intertia.ipynb
# Out:
# Avg angular velocity before:  7.696702551897629 . uncertainty:  0.5575044050916235
# Avg angular velocity after:  4.810103264820133 . uncertainty:  0.04002411893086095
# Avg intertia of the weight:  5.666560090117742e-05
# Average intertial of the object:  9.442508806745596e-05 . uncertainty:  7.856964282886757e-07

# %%
CSV_INPUT = "./H.csv"
# %run ./find_intertia.ipynb
# Out:
# Avg angular velocity before:  4.34472679161872 . uncertainty:  0.09424556117097674
# Avg angular velocity after:  3.876773236213443 . uncertainty:  0.033281802881792034
# Avg intertia of the weight:  9.849234254835331e-05
# Average intertial of the object:  0.0008159623388964991 . uncertainty:  7.0049745155184806e-06
